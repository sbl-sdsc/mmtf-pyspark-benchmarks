# %% [markdown]
# ## Benchmark MMTF Hadoop Sequence File reading

# %%
import pandas as pd
import papermill as pm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import psutil
n_cores = psutil.cpu_count(logical=True)
n_cpus = psutil.cpu_count(logical=False)
print("cores:", n_cores)
print("cpus: ", n_cpus)
# Out:
# cores: 4
# cpus:  2

# %%
dataset = "full"
coresets = [1,2,3] + list(range(4, n_cores+1, 4))
print(coresets)
# Out:
# [1, 2, 3, 4]

# %%
for cores in coresets:
    pm.execute_notebook(
        'tasks/Read.ipynb',
        '../output/Read_' + str(cores) + "_" + dataset + '.ipynb',
        parameters = dict(cores=cores, path='../data/' + dataset)
    )
# Out:
# Input Notebook:  tasks/Read.ipynb
# Output Notebook: ../output/Read_1_full.ipynb
# 100%|██████████| 7/7 [01:22<00:00, 11.74s/it]
# Input Notebook:  tasks/Read.ipynb
# Output Notebook: ../output/Read_2_full.ipynb
# 100%|██████████| 7/7 [00:55<00:00,  7.92s/it]
# Input Notebook:  tasks/Read.ipynb
# Output Notebook: ../output/Read_3_full.ipynb
# 100%|██████████| 7/7 [00:55<00:00,  7.98s/it]
# Input Notebook:  tasks/Read.ipynb
# Output Notebook: ../output/Read_4_full.ipynb
# 100%|██████████| 7/7 [00:56<00:00,  8.11s/it]

# %%
nbs = pm.read_notebooks('../output/')
nbs.dataframe
# Out:
#             name         value       type             filename  \
# 0          cores             1  parameter  Filter_1_full.ipynb
# 1           path  ../data/full  parameter  Filter_1_full.ipynb
# 2         filter       62.5429     record  Filter_1_full.ipynb
# 3   filter_total       80.7885     record  Filter_1_full.ipynb
# 4          cores             2  parameter  Filter_2_full.ipynb
# 5           path  ../data/full  parameter  Filter_2_full.ipynb
# 6         filter       35.8053     record  Filter_2_full.ipynb
# 7   filter_total       54.0278     record  Filter_2_full.ipynb
# 8          cores             3  parameter  Filter_3_full.ipynb
# 9           path  ../data/full  parameter  Filter_3_full.ipynb
# 10        filter       36.6299     record  Filter_3_full.ipynb
# 11  filter_total       54.9289     record  Filter_3_full.ipynb
# 12         cores             4  parameter  Filter_4_full.ipynb
# 13          path  ../data/full  parameter  Filter_4_full.ipynb
# 14        filter        37.406     record  Filter_4_full.ipynb
# 15  filter_total       55.6387     record  Filter_4_full.ipynb
# 16         cores             1  parameter    Read_1_full.ipynb
# 17          path  ../data/full  parameter    Read_1_full.ipynb
# 18          read       61.5972     record    Read_1_full.ipynb
# 19    read_total       79.8409     record    Read_1_full.ipynb
# 20         cores             2  parameter    Read_2_full.ipynb
# 21          path  ../data/full  parameter    Read_2_full.ipynb
# 22          read       34.8398     record    Read_2_full.ipynb
# 23    read_total       53.0796     record    Read_2_full.ipynb
# 24         cores             3  parameter    Read_3_full.ipynb
# 25          path  ../data/full  parameter    Read_3_full.ipynb
# 26          read       35.2844     record    Read_3_full.ipynb
# 27    read_total       53.5376     record    Read_3_full.ipynb
# 28         cores             4  parameter    Read_4_full.ipynb
# 29          path  ../data/full  parameter    Read_4_full.ipynb
# 30          read       36.0636     record    Read_4_full.ipynb
# 31    read_total       54.3637     record    Read_4_full.ipynb
#
#                     key
# 0   Filter_1_full.ipynb
# 1   Filter_1_full.ipynb
# 2   Filter_1_full.ipynb
# 3   Filter_1_full.ipynb
# 4   Filter_2_full.ipynb
# 5   Filter_2_full.ipynb
# 6   Filter_2_full.ipynb
# 7   Filter_2_full.ipynb
# 8   Filter_3_full.ipynb
# 9   Filter_3_full.ipynb
# 10  Filter_3_full.ipynb
# 11  Filter_3_full.ipynb
# 12  Filter_4_full.ipynb
# 13  Filter_4_full.ipynb
# 14  Filter_4_full.ipynb
# 15  Filter_4_full.ipynb
# 16    Read_1_full.ipynb
# 17    Read_1_full.ipynb
# 18    Read_1_full.ipynb
# 19    Read_1_full.ipynb
# 20    Read_2_full.ipynb
# 21    Read_2_full.ipynb
# 22    Read_2_full.ipynb
# 23    Read_2_full.ipynb
# 24    Read_3_full.ipynb
# 25    Read_3_full.ipynb
# 26    Read_3_full.ipynb
# 27    Read_3_full.ipynb
# 28    Read_4_full.ipynb
# 29    Read_4_full.ipynb
# 30    Read_4_full.ipynb
# 31    Read_4_full.ipynb

# %%
df = nbs.dataframe.pivot(index='key', columns='name', values='value')
df["cores"] = pd.to_numeric(df["cores"])
df["read"] = pd.to_numeric(df["read"])
df
# Out:
# name                 cores   filter filter_total          path       read  \
# key
# Filter_1_full.ipynb      1  62.5429      80.7885  ../data/full        NaN
# Filter_2_full.ipynb      2  35.8053      54.0278  ../data/full        NaN
# Filter_3_full.ipynb      3  36.6299      54.9289  ../data/full        NaN
# Filter_4_full.ipynb      4   37.406      55.6387  ../data/full        NaN
# Read_1_full.ipynb        1     None         None  ../data/full  61.597179
# Read_2_full.ipynb        2     None         None  ../data/full  34.839754
# Read_3_full.ipynb        3     None         None  ../data/full  35.284431
# Read_4_full.ipynb        4     None         None  ../data/full  36.063575
#
# name                read_total
# key
# Filter_1_full.ipynb       None
# Filter_2_full.ipynb       None
# Filter_3_full.ipynb       None
# Filter_4_full.ipynb       None
# Read_1_full.ipynb      79.8409
# Read_2_full.ipynb      53.0796
# Read_3_full.ipynb      53.5376
# Read_4_full.ipynb      54.3637

# %%
ds = df.filter(like='Read', axis=0)
ds.to_csv("../results/Read.csv")
