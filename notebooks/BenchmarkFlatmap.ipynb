# %% [markdown]
# ## Benchmark MMTF Hadoop Sequence File flatmapping

# %%
import pandas as pd
import papermill as pm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import psutil
n_cores = psutil.cpu_count(logical=True)
n_cpus = psutil.cpu_count(logical=False)
print("cores:", n_cores)
print("cpus: ", n_cpus)
# Out:
# cores: 4
# cpus:  2

# %%
dataset = "full"
coresets = [1,2,3] + list(range(4, n_cores+1, 4))
print(coresets)
# Out:
# [1, 2, 3, 4]

# %%
for cores in coresets:
    pm.execute_notebook(
        'tasks/Flatmap.ipynb',
        '../output/Flatmap_' + str(cores) + "_" + dataset + '.ipynb',
        parameters = dict(cores=cores, path='../data/' + dataset)
    )
# Out:
# Input Notebook:  tasks/Flatmap.ipynb
# Output Notebook: ../output/Flatmap_1_full.ipynb
# 100%|██████████| 7/7 [04:07<00:00, 35.40s/it]
# Input Notebook:  tasks/Flatmap.ipynb
# Output Notebook: ../output/Flatmap_2_full.ipynb
# 100%|██████████| 7/7 [02:23<00:00, 20.53s/it]
# Input Notebook:  tasks/Flatmap.ipynb
# Output Notebook: ../output/Flatmap_3_full.ipynb
# 100%|██████████| 7/7 [02:27<00:00, 21.05s/it]
# Input Notebook:  tasks/Flatmap.ipynb
# Output Notebook: ../output/Flatmap_4_full.ipynb
# 100%|██████████| 7/7 [02:29<00:00, 21.42s/it]

# %%
nbs = pm.read_notebooks('../output/')
nbs.dataframe
# Out:
#              name         value       type              filename  \
# 0           cores             1  parameter   Filter_1_full.ipynb
# 1            path  ../data/full  parameter   Filter_1_full.ipynb
# 2          filter       62.5429     record   Filter_1_full.ipynb
# 3    filter_total       80.7885     record   Filter_1_full.ipynb
# 4           cores             2  parameter   Filter_2_full.ipynb
# 5            path  ../data/full  parameter   Filter_2_full.ipynb
# 6          filter       35.8053     record   Filter_2_full.ipynb
# 7    filter_total       54.0278     record   Filter_2_full.ipynb
# 8           cores             3  parameter   Filter_3_full.ipynb
# 9            path  ../data/full  parameter   Filter_3_full.ipynb
# 10         filter       36.6299     record   Filter_3_full.ipynb
# 11   filter_total       54.9289     record   Filter_3_full.ipynb
# 12          cores             4  parameter   Filter_4_full.ipynb
# 13           path  ../data/full  parameter   Filter_4_full.ipynb
# 14         filter        37.406     record   Filter_4_full.ipynb
# 15   filter_total       55.6387     record   Filter_4_full.ipynb
# 16          cores             1  parameter  Flatmap_1_full.ipynb
# 17           path  ../data/full  parameter  Flatmap_1_full.ipynb
# 18        flatmap       226.961     record  Flatmap_1_full.ipynb
# 19  flatmap_total       245.348     record  Flatmap_1_full.ipynb
# 20          cores             2  parameter  Flatmap_2_full.ipynb
# 21           path  ../data/full  parameter  Flatmap_2_full.ipynb
# 22        flatmap       122.753     record  Flatmap_2_full.ipynb
# 23  flatmap_total       141.234     record  Flatmap_2_full.ipynb
# 24          cores             3  parameter  Flatmap_3_full.ipynb
# 25           path  ../data/full  parameter  Flatmap_3_full.ipynb
# 26        flatmap       126.704     record  Flatmap_3_full.ipynb
# 27  flatmap_total       144.965     record  Flatmap_3_full.ipynb
# 28          cores             4  parameter  Flatmap_4_full.ipynb
# 29           path  ../data/full  parameter  Flatmap_4_full.ipynb
# 30        flatmap       129.304     record  Flatmap_4_full.ipynb
# 31  flatmap_total       147.564     record  Flatmap_4_full.ipynb
# 32          cores             1  parameter     Read_1_full.ipynb
# 33           path  ../data/full  parameter     Read_1_full.ipynb
# 34           read       61.5972     record     Read_1_full.ipynb
# 35     read_total       79.8409     record     Read_1_full.ipynb
# 36          cores             2  parameter     Read_2_full.ipynb
# 37           path  ../data/full  parameter     Read_2_full.ipynb
# 38           read       34.8398     record     Read_2_full.ipynb
# 39     read_total       53.0796     record     Read_2_full.ipynb
# 40          cores             3  parameter     Read_3_full.ipynb
# 41           path  ../data/full  parameter     Read_3_full.ipynb
# 42           read       35.2844     record     Read_3_full.ipynb
# 43     read_total       53.5376     record     Read_3_full.ipynb
# 44          cores             4  parameter     Read_4_full.ipynb
# 45           path  ../data/full  parameter     Read_4_full.ipynb
# 46           read       36.0636     record     Read_4_full.ipynb
# 47     read_total       54.3637     record     Read_4_full.ipynb
#
#                      key
# 0    Filter_1_full.ipynb
# 1    Filter_1_full.ipynb
# 2    Filter_1_full.ipynb
# 3    Filter_1_full.ipynb
# 4    Filter_2_full.ipynb
# 5    Filter_2_full.ipynb
# 6    Filter_2_full.ipynb
# 7    Filter_2_full.ipynb
# 8    Filter_3_full.ipynb
# 9    Filter_3_full.ipynb
# 10   Filter_3_full.ipynb
# 11   Filter_3_full.ipynb
# 12   Filter_4_full.ipynb
# 13   Filter_4_full.ipynb
# 14   Filter_4_full.ipynb
# 15   Filter_4_full.ipynb
# 16  Flatmap_1_full.ipynb
# 17  Flatmap_1_full.ipynb
# 18  Flatmap_1_full.ipynb
# 19  Flatmap_1_full.ipynb
# 20  Flatmap_2_full.ipynb
# 21  Flatmap_2_full.ipynb
# 22  Flatmap_2_full.ipynb
# 23  Flatmap_2_full.ipynb
# 24  Flatmap_3_full.ipynb
# 25  Flatmap_3_full.ipynb
# 26  Flatmap_3_full.ipynb
# 27  Flatmap_3_full.ipynb
# 28  Flatmap_4_full.ipynb
# 29  Flatmap_4_full.ipynb
# 30  Flatmap_4_full.ipynb
# 31  Flatmap_4_full.ipynb
# 32     Read_1_full.ipynb
# 33     Read_1_full.ipynb
# 34     Read_1_full.ipynb
# 35     Read_1_full.ipynb
# 36     Read_2_full.ipynb
# 37     Read_2_full.ipynb
# 38     Read_2_full.ipynb
# 39     Read_2_full.ipynb
# 40     Read_3_full.ipynb
# 41     Read_3_full.ipynb
# 42     Read_3_full.ipynb
# 43     Read_3_full.ipynb
# 44     Read_4_full.ipynb
# 45     Read_4_full.ipynb
# 46     Read_4_full.ipynb
# 47     Read_4_full.ipynb

# %%
df = nbs.dataframe.pivot(index='key', columns='name', values='value')
df["cores"] = pd.to_numeric(df["cores"])
df["flatmap"] = pd.to_numeric(df["flatmap"])
df
# Out:
# name                  cores   filter filter_total     flatmap flatmap_total  \
# key
# Filter_1_full.ipynb       1  62.5429      80.7885         NaN          None
# Filter_2_full.ipynb       2  35.8053      54.0278         NaN          None
# Filter_3_full.ipynb       3  36.6299      54.9289         NaN          None
# Filter_4_full.ipynb       4   37.406      55.6387         NaN          None
# Flatmap_1_full.ipynb      1     None         None  226.961150       245.348
# Flatmap_2_full.ipynb      2     None         None  122.753293       141.234
# Flatmap_3_full.ipynb      3     None         None  126.704003       144.965
# Flatmap_4_full.ipynb      4     None         None  129.303737       147.564
# Read_1_full.ipynb         1     None         None         NaN          None
# Read_2_full.ipynb         2     None         None         NaN          None
# Read_3_full.ipynb         3     None         None         NaN          None
# Read_4_full.ipynb         4     None         None         NaN          None
#
# name                          path     read read_total
# key
# Filter_1_full.ipynb   ../data/full     None       None
# Filter_2_full.ipynb   ../data/full     None       None
# Filter_3_full.ipynb   ../data/full     None       None
# Filter_4_full.ipynb   ../data/full     None       None
# Flatmap_1_full.ipynb  ../data/full     None       None
# Flatmap_2_full.ipynb  ../data/full     None       None
# Flatmap_3_full.ipynb  ../data/full     None       None
# Flatmap_4_full.ipynb  ../data/full     None       None
# Read_1_full.ipynb     ../data/full  61.5972    79.8409
# Read_2_full.ipynb     ../data/full  34.8398    53.0796
# Read_3_full.ipynb     ../data/full  35.2844    53.5376
# Read_4_full.ipynb     ../data/full  36.0636    54.3637

# %%
ds = df.filter(like='Flatmap', axis=0)
ds.to_csv("../results/Flatmap.csv")
