# %% [markdown]
# ## Benchmark MMTF Hadoop Sequence File filtering

# %%
import pandas as pd
import papermill as pm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import psutil
n_cores = psutil.cpu_count(logical=True)
n_cpus = psutil.cpu_count(logical=False)
print("cores:", n_cores)
print("cpus: ", n_cpus)
# Out:
# cores: 8
# cpus:  4

# %%
dataset = "full"
coresets = [1,2,3] + list(range(4, n_cores+1, 4))
print(coresets)
# Out:
# [1, 2, 3, 4, 8]

# %%
for cores in coresets:
    pm.execute_notebook(
        'tasks/Filter.ipynb',
        '../output/Filter_' + str(cores) + "_" + dataset + '.ipynb',
        parameters = dict(cores=cores, path='../data/' + dataset)
    )
# Out:
# Input Notebook:  tasks/Filter.ipynb
# Output Notebook: ../output/Filter_1_full.ipynb
# 100%|██████████| 7/7 [22:24<00:00, 192.03s/it]
# Input Notebook:  tasks/Filter.ipynb
# Output Notebook: ../output/Filter_2_full.ipynb
# 100%|██████████| 7/7 [11:57<00:00, 102.57s/it]
# Input Notebook:  tasks/Filter.ipynb
# Output Notebook: ../output/Filter_3_full.ipynb
# 100%|██████████| 7/7 [08:54<00:00, 76.33s/it]
# Input Notebook:  tasks/Filter.ipynb
# Output Notebook: ../output/Filter_4_full.ipynb
# 100%|██████████| 7/7 [07:21<00:00, 63.02s/it]
# Input Notebook:  tasks/Filter.ipynb
# Output Notebook: ../output/Filter_8_full.ipynb
# 100%|██████████| 7/7 [06:29<00:00, 55.64s/it]

# %%
nbs = pm.read_notebooks('../output/')
nbs.dataframe
# Out:
#                  name         value       type                  filename  \
# 0               cores             1  parameter       Filter_1_full.ipynb
# 1                path  ../data/full  parameter       Filter_1_full.ipynb
# 2              filter       1323.15     record       Filter_1_full.ipynb
# 3        filter_total       1341.47     record       Filter_1_full.ipynb
# 4               cores             2  parameter       Filter_2_full.ipynb
# 5                path  ../data/full  parameter       Filter_2_full.ipynb
# 6              filter       696.475     record       Filter_2_full.ipynb
# 7        filter_total       714.854     record       Filter_2_full.ipynb
# 8               cores             3  parameter       Filter_3_full.ipynb
# 9                path  ../data/full  parameter       Filter_3_full.ipynb
# 10             filter       512.475     record       Filter_3_full.ipynb
# 11       filter_total       531.107     record       Filter_3_full.ipynb
# 12              cores             4  parameter       Filter_4_full.ipynb
# 13               path  ../data/full  parameter       Filter_4_full.ipynb
# 14             filter       419.321     record       Filter_4_full.ipynb
# 15       filter_total       437.898     record       Filter_4_full.ipynb
# 16              cores             8  parameter       Filter_8_full.ipynb
# 17               path  ../data/full  parameter       Filter_8_full.ipynb
# 18             filter       367.798     record       Filter_8_full.ipynb
# 19       filter_total       386.289     record       Filter_8_full.ipynb
# 20              cores             1  parameter  Fingerprint_1_full.ipynb
# 21               path  ../data/full  parameter  Fingerprint_1_full.ipynb
# 22        fingerprint       7832.17     record  Fingerprint_1_full.ipynb
# 23  fingerprint_total       7850.59     record  Fingerprint_1_full.ipynb
# 24              cores             2  parameter  Fingerprint_2_full.ipynb
# 25               path  ../data/full  parameter  Fingerprint_2_full.ipynb
# 26        fingerprint       4004.09     record  Fingerprint_2_full.ipynb
# 27  fingerprint_total       4022.47     record  Fingerprint_2_full.ipynb
# 28              cores             3  parameter  Fingerprint_3_full.ipynb
# 29               path  ../data/full  parameter  Fingerprint_3_full.ipynb
# ..                ...           ...        ...                       ...
# 50            flatmap       2470.08     record      Flatmap_3_full.ipynb
# 51      flatmap_total       2488.55     record      Flatmap_3_full.ipynb
# 52              cores             4  parameter      Flatmap_4_full.ipynb
# 53               path  ../data/full  parameter      Flatmap_4_full.ipynb
# 54            flatmap       1968.31     record      Flatmap_4_full.ipynb
# 55      flatmap_total        1986.6     record      Flatmap_4_full.ipynb
# 56              cores             8  parameter      Flatmap_8_full.ipynb
# 57               path  ../data/full  parameter      Flatmap_8_full.ipynb
# 58            flatmap       1931.44     record      Flatmap_8_full.ipynb
# 59      flatmap_total       1950.03     record      Flatmap_8_full.ipynb
# 60              cores             1  parameter         Read_1_full.ipynb
# 61               path  ../data/full  parameter         Read_1_full.ipynb
# 62               read       1278.53     record         Read_1_full.ipynb
# 63         read_total       1296.85     record         Read_1_full.ipynb
# 64              cores             2  parameter         Read_2_full.ipynb
# 65               path  ../data/full  parameter         Read_2_full.ipynb
# 66               read       668.032     record         Read_2_full.ipynb
# 67         read_total       686.362     record         Read_2_full.ipynb
# 68              cores             3  parameter         Read_3_full.ipynb
# 69               path  ../data/full  parameter         Read_3_full.ipynb
# 70               read        470.32     record         Read_3_full.ipynb
# 71         read_total       488.658     record         Read_3_full.ipynb
# 72              cores             4  parameter         Read_4_full.ipynb
# 73               path  ../data/full  parameter         Read_4_full.ipynb
# 74               read       387.979     record         Read_4_full.ipynb
# 75         read_total       406.317     record         Read_4_full.ipynb
# 76              cores             8  parameter         Read_8_full.ipynb
# 77               path  ../data/full  parameter         Read_8_full.ipynb
# 78               read         342.4     record         Read_8_full.ipynb
# 79         read_total       360.765     record         Read_8_full.ipynb
#
#                          key
# 0        Filter_1_full.ipynb
# 1        Filter_1_full.ipynb
# 2        Filter_1_full.ipynb
# 3        Filter_1_full.ipynb
# 4        Filter_2_full.ipynb
# 5        Filter_2_full.ipynb
# 6        Filter_2_full.ipynb
# 7        Filter_2_full.ipynb
# 8        Filter_3_full.ipynb
# 9        Filter_3_full.ipynb
# 10       Filter_3_full.ipynb
# 11       Filter_3_full.ipynb
# 12       Filter_4_full.ipynb
# 13       Filter_4_full.ipynb
# 14       Filter_4_full.ipynb
# 15       Filter_4_full.ipynb
# 16       Filter_8_full.ipynb
# 17       Filter_8_full.ipynb
# 18       Filter_8_full.ipynb
# 19       Filter_8_full.ipynb
# 20  Fingerprint_1_full.ipynb
# 21  Fingerprint_1_full.ipynb
# 22  Fingerprint_1_full.ipynb
# 23  Fingerprint_1_full.ipynb
# 24  Fingerprint_2_full.ipynb
# 25  Fingerprint_2_full.ipynb
# 26  Fingerprint_2_full.ipynb
# 27  Fingerprint_2_full.ipynb
# 28  Fingerprint_3_full.ipynb
# 29  Fingerprint_3_full.ipynb
# ..                       ...
# 50      Flatmap_3_full.ipynb
# 51      Flatmap_3_full.ipynb
# 52      Flatmap_4_full.ipynb
# 53      Flatmap_4_full.ipynb
# 54      Flatmap_4_full.ipynb
# 55      Flatmap_4_full.ipynb
# 56      Flatmap_8_full.ipynb
# 57      Flatmap_8_full.ipynb
# 58      Flatmap_8_full.ipynb
# 59      Flatmap_8_full.ipynb
# 60         Read_1_full.ipynb
# 61         Read_1_full.ipynb
# 62         Read_1_full.ipynb
# 63         Read_1_full.ipynb
# 64         Read_2_full.ipynb
# 65         Read_2_full.ipynb
# 66         Read_2_full.ipynb
# 67         Read_2_full.ipynb
# 68         Read_3_full.ipynb
# 69         Read_3_full.ipynb
# 70         Read_3_full.ipynb
# 71         Read_3_full.ipynb
# 72         Read_4_full.ipynb
# 73         Read_4_full.ipynb
# 74         Read_4_full.ipynb
# 75         Read_4_full.ipynb
# 76         Read_8_full.ipynb
# 77         Read_8_full.ipynb
# 78         Read_8_full.ipynb
# 79         Read_8_full.ipynb
#
# [80 rows x 5 columns]

# %%
df = nbs.dataframe.pivot(index='key', columns='name', values='value')
df["cores"] = pd.to_numeric(df["cores"])
df["filter"] = pd.to_numeric(df["filter"])
df
# Out:
# name                      cores       filter filter_total fingerprint  \
# key
# Filter_1_full.ipynb           1  1323.152774      1341.47         NaN
# Filter_2_full.ipynb           2   696.475280      714.854         NaN
# Filter_3_full.ipynb           3   512.475331      531.107         NaN
# Filter_4_full.ipynb           4   419.320728      437.898         NaN
# Filter_8_full.ipynb           8   367.797722      386.289         NaN
# Fingerprint_1_full.ipynb      1          NaN          NaN     7832.17
# Fingerprint_2_full.ipynb      2          NaN          NaN     4004.09
# Fingerprint_3_full.ipynb      3          NaN          NaN     2778.45
# Fingerprint_4_full.ipynb      4          NaN          NaN     2370.01
# Fingerprint_8_full.ipynb      8          NaN          NaN     2460.32
# Flatmap_1_full.ipynb          1          NaN          NaN         NaN
# Flatmap_2_full.ipynb          2          NaN          NaN         NaN
# Flatmap_3_full.ipynb          3          NaN          NaN         NaN
# Flatmap_4_full.ipynb          4          NaN          NaN         NaN
# Flatmap_8_full.ipynb          8          NaN          NaN         NaN
# Read_1_full.ipynb             1          NaN          NaN         NaN
# Read_2_full.ipynb             2          NaN          NaN         NaN
# Read_3_full.ipynb             3          NaN          NaN         NaN
# Read_4_full.ipynb             4          NaN          NaN         NaN
# Read_8_full.ipynb             8          NaN          NaN         NaN
#
# name                     fingerprint_total  flatmap flatmap_total  \
# key
# Filter_1_full.ipynb                    NaN      NaN           NaN
# Filter_2_full.ipynb                    NaN      NaN           NaN
# Filter_3_full.ipynb                    NaN      NaN           NaN
# Filter_4_full.ipynb                    NaN      NaN           NaN
# Filter_8_full.ipynb                    NaN      NaN           NaN
# Fingerprint_1_full.ipynb           7850.59      NaN           NaN
# Fingerprint_2_full.ipynb           4022.47      NaN           NaN
# Fingerprint_3_full.ipynb           2796.98      NaN           NaN
# Fingerprint_4_full.ipynb           2388.62      NaN           NaN
# Fingerprint_8_full.ipynb            2478.9      NaN           NaN
# Flatmap_1_full.ipynb                   NaN  7557.07       7575.37
# Flatmap_2_full.ipynb                   NaN  3632.11       3650.68
# Flatmap_3_full.ipynb                   NaN  2470.08       2488.55
# Flatmap_4_full.ipynb                   NaN  1968.31        1986.6
# Flatmap_8_full.ipynb                   NaN  1931.44       1950.03
# Read_1_full.ipynb                      NaN      NaN           NaN
# Read_2_full.ipynb                      NaN      NaN           NaN
# Read_3_full.ipynb                      NaN      NaN           NaN
# Read_4_full.ipynb                      NaN      NaN           NaN
# Read_8_full.ipynb                      NaN      NaN           NaN
#
# name                              path     read read_total
# key
# Filter_1_full.ipynb       ../data/full      NaN        NaN
# Filter_2_full.ipynb       ../data/full      NaN        NaN
# Filter_3_full.ipynb       ../data/full      NaN        NaN
# Filter_4_full.ipynb       ../data/full      NaN        NaN
# Filter_8_full.ipynb       ../data/full      NaN        NaN
# Fingerprint_1_full.ipynb  ../data/full      NaN        NaN
# Fingerprint_2_full.ipynb  ../data/full      NaN        NaN
# Fingerprint_3_full.ipynb  ../data/full      NaN        NaN
# Fingerprint_4_full.ipynb  ../data/full      NaN        NaN
# Fingerprint_8_full.ipynb  ../data/full      NaN        NaN
# Flatmap_1_full.ipynb      ../data/full      NaN        NaN
# Flatmap_2_full.ipynb      ../data/full      NaN        NaN
# Flatmap_3_full.ipynb      ../data/full      NaN        NaN
# Flatmap_4_full.ipynb      ../data/full      NaN        NaN
# Flatmap_8_full.ipynb      ../data/full      NaN        NaN
# Read_1_full.ipynb         ../data/full  1278.53    1296.85
# Read_2_full.ipynb         ../data/full  668.032    686.362
# Read_3_full.ipynb         ../data/full   470.32    488.658
# Read_4_full.ipynb         ../data/full  387.979    406.317
# Read_8_full.ipynb         ../data/full    342.4    360.765

# %%
ds = df.filter(like='Filter', axis=0)
ds.to_csv("../results/Filter.csv")
